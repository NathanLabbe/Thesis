# %%
import csv             # j'importe le module csv
import codecs
import xml.etree.ElementTree as ET
import os

# %%
# !dir
# Out:
#  Le volume dans le lecteur C sâ€™appelle OS
#  Le numÃ©ro de sÃ©rie du volume est D413-8018
#
#  RÃ©pertoire de C:\Users\natha\Documents\Keep\Cours\KTH\Master Thesis\personalRepo\Thesis\images\allImages
#
# 16/02/2021  18:43    <DIR>          .
# 16/02/2021  18:43    <DIR>          ..
# 16/02/2021  18:19    <DIR>          .ipynb_checkpoints
# 16/02/2021  17:11    <DIR>          imagesAndAugAGRI
# 16/02/2021  17:16    <DIR>          imagesAndAugTRUE
# 16/02/2021  18:28           357Â 419 labelAGRI.csv
# 16/02/2021  17:15           359Â 469 labelTRUE.csv
# 16/02/2021  18:43           524Â 224 RemoveDotInCsv.ipynb
# 16/02/2021  17:25    <DIR>          retinanet_csv_format
#                3 fichier(s)        1Â 241Â 112 octets
#                6 RÃ©p(s)  19Â 168Â 976Â 896 octets libres

# %%
path ='../../../../images/AGRI_LAB/' 
for element in os.listdir('../../../../images/AGRI_LAB'):
    if not os.path.isdir(element):
        print(element)
        tree = ET.parse(path+str(element))
        root = tree.getroot()

# changing a field text

        for elem in root.iter('filename'):
            elem.text = str(element)

    tree.write(str(element))                     #je ferme le fichier
# Out:
# -52_19-0_58_2019-09-24.xml
# -52_19-0_62_2019-09-24.xml
# -52_19-0_66_2019-09-24.xml
# -52_19-0_7_2019-09-24.xml
# -52_23-0_62_2019-09-24.xml
# -52_23-0_66_2019-09-24.xml
# -52_27-0_58_2019-09-24.xml
# -52_27-0_62_2019-09-24.xml
# -52_27-0_66_2019-09-24.xml
# -52_27-0_74_2019-09-24.xml
# -52_27-0_7_2019-09-24.xml
# -52_31-0_62_2019-09-24.xml
# -52_31-0_66_2019-09-24.xml
# -52_31-0_74_2019-09-24.xml
# -52_31-0_7_2019-09-24.xml
# -52_35-0_58_2019-09-24.xml
# -52_35-0_62_2019-09-24.xml
# -52_35-0_66_2019-09-24.xml
# -52_35-0_74_2019-09-24.xml
# -52_35-0_7_2019-09-24.xml
# -52_95--0_03_2018-10-14.xml
# -52_95--0_11_2018-10-14.xml
# -52_95--0_15_2018-10-14.xml
# -52_95--0_19_2018-10-14.xml
# -52_95--0_23_2018-10-14.xml
# -52_95--0_27_2018-10-14.xml
# -52_95--0_31_2018-10-14.xml
# -52_95-0_05_2018-10-14.xml
# -52_98-0_07_2019-09-24.xml
# -52_98-0_11_2019-09-24.xml
# -52_98-0_15_2019-09-24.xml
# -52_98-0_19_2019-09-24.xml
# -52_98-0_23_2019-09-24.xml
# -52_98-0_27_2019-09-24.xml
# ...
