# %%
from PIL import Image
import os
import os.path
import random
import shutil
from IPython.display import display

# %%
i = open("./legalAgri - Copie/data/test/label/-56_16__-2_58_2020-09-06.jpg")
display(i)
(largeur, hauteur)= i.size
for x in range(largeur):
    for y in range(hauteur):
        r= i.getpixel((x,y))
        if r <= 127 :
            i.putpixel((x,y),0)
        else :
            i.putpixel((x,y),0)
        #print("r="+str(r))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1000x1000 at 0x7F25FABF6910>
