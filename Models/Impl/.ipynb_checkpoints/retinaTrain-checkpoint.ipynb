# %%
#Debug Retinanet 
# !python ../keras-retinanet/keras_retinanet/bin/debug.py  csv ../../images/retina/illegal_Agri/csv/annotations.csv ../../images/retina/illegal_Agri/csv/classes.csv
# Out:
# 2021-02-25 12:10:37.035089: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# usage: debug.py [-h] [--no-resize] [--anchors] [--display-name]
#                 [--show-annotations] [--random-transform]
#                 [--image-min-side IMAGE_MIN_SIDE]
#                 [--image-max-side IMAGE_MAX_SIDE] [--config CONFIG] [--no-gui]
#                 [--output-dir OUTPUT_DIR] [--flatten-output]
#                 [--group-method {none,random,ratio}]
#                 {coco,pascal,kitti,oid,csv} ...
# debug.py: error: argument dataset_type: invalid choice: '901' (choose from 'coco', 'pascal', 'kitti', 'oid', 'csv')

# %%
# !python ../keras-retinanet/keras_retinanet/bin/train.py --freeze-backbone --random-transform --weights {PRETRAINED_MODEL} --batch-size 8 --steps 500 --epochs 15 csv ../../images/retina/illegal_Agri/csv/annotations.csv ../../images/retina/illegal_Agri/csv/classes.csv

# %%
# !python ../keras-retinanet/keras_retinanet/bin/train.py --backbone resnet101 --weights path/to/weights.h5 --epochs 100 --snapshot-path path/to/save/dir --tensorboard-dir path/to/tensorboard/dir csv path/to/annotations.csv path/to/classes.csv

# %%
BEGINNING TRAINING
# Out:
#   File "<ipython-input-9-e37c9ce8be7a>", line 1
#     BEGINNING TRAINING
#                      ^
# SyntaxError: invalid syntax

# %%
#TRAIN LegalAgri No Aug ResNet 50  #DONE
# !python ../keras-retinanet/keras_retinanet/bin/train.py --lr 5e-4 --reduce-lr-patience 2 --reduce-lr-factor 0.5 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --epochs 100 --batch-size 4 --snapshot-path ../keras-retinanet/snapshots/saves --tensorboard-dir ../../tensor/RetinaNet_Legal_Agri --weighted-average csv ../../images/retina/legal_Agri_noAug/csv/annotations.csv ../../images/retina/legal_Agri_noAug/csv/classes.csv --val-annotations ../../images/retina/legal_Agri_noAug/csv/val_annotations.csv
# Out:
# 2021-03-22 17:26:08.880461: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-03-22 17:26:09.861576: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-22 17:26:09.862161: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-22 17:26:09.905920: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-22 17:26:09.906743: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
#TRAIN LegalTrue No Aug ResNet 50
# !python ../keras-retinanet/keras_retinanet/bin/train.py --lr 5e-4 --reduce-lr-patience 2 --reduce-lr-factor 0.1 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --epochs 100 --batch-size 4 --snapshot-path ../keras-retinanet/snapshots/saves --tensorboard-dir ../../tensor/RetinaNet_Legal_True --weighted-average csv ../../images/retina/legal_True_noAug/csv/annotations.csv ../../images/retina/legal_True_noAug/csv/classes.csv --val-annotations ../../images/retina/legal_True_noAug/csv/val_annotations.csv
# Out:
# 2021-03-22 16:57:42.196311: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-03-22 16:57:43.152021: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-22 16:57:43.152592: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-22 16:57:43.195106: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-22 16:57:43.195764: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
#TRAIN IlegalAgri No Aug ResNet 50
# !python ../keras-retinanet/keras_retinanet/bin/train.py --lr 1e-4 --reduce-lr-patience 2 --reduce-lr-factor 0.1 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --epochs 100 --batch-size 4 --snapshot-path ../keras-retinanet/snapshots/saves --tensorboard-dir ../../tensor/RetinaNet_Ilegal_Agri --weighted-average csv ../../images/retina/illegal_Agri_noAug/csv/annotations.csv ../../images/retina/illegal_Agri_noAug/csv/classes.csv --val-annotations ../../images/retina/illegal_Agri_noAug/csv/val_annotations.csv
# Out:
# 2021-03-22 17:17:27.808375: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-03-22 17:17:31.426551: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-22 17:17:31.431051: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-22 17:17:31.492151: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-22 17:17:31.493099: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
#evaluate
# !python ../keras-retinanet/keras_retinanet/bin/evaluate.py csv ../../images/retina/illegal_Agri_noAug/csv/val_annotations.csv ../../images/retina/illegal_Agri_noAug/csv/classes.csv ../keras-retinanet/snapshots/saves/inference/model.h5
# Out:
# 2021-02-25 15:16:35.953447: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Loading model, this may take a second...
# 2021-02-25 15:16:36.941933: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-25 15:16:36.942522: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-02-25 15:16:36.978725: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 15:16:36.979332: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...
