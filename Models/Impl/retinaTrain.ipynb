# %%
#Debug Retinanet 
# !python ../keras-retinanet/keras_retinanet/bin/debug.py  csv ../../images/retina/illegal_True_noAug/csv/val_annotations.csv ../../images/retina/illegal_True_noAug/csv/classes.csv
# Out:
# 2021-03-23 10:41:15.260072: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Traceback (most recent call last):
#   File "../keras-retinanet/keras_retinanet/bin/debug.py", line 321, in <module>
#     main()
#   File "../keras-retinanet/keras_retinanet/bin/debug.py", line 299, in main
#     generator = create_generator(args)
#   File "../keras-retinanet/keras_retinanet/bin/debug.py", line 112, in create_generator
#     **common_args
#   File "../keras-retinanet/keras_retinanet/bin/../../keras_retinanet/preprocessing/csv_generator.py", line 161, in __init__
#     super(CSVGenerator, self).__init__(**kwargs)
#   File "../keras-retinanet/keras_retinanet/bin/../../keras_retinanet/preprocessing/generator.py", line 89, in __init__
#     self.group_images()
#   File "../keras-retinanet/keras_retinanet/bin/../../keras_retinanet/preprocessing/generator.py", line 291, in group_images
# ...

# %%
# !python ../keras-retinanet/keras_retinanet/bin/train.py --freeze-backbone --random-transform --weights {PRETRAINED_MODEL} --batch-size 8 --steps 500 --epochs 15 csv ../../images/retina/illegal_Agri/csv/annotations.csv ../../images/retina/illegal_Agri/csv/classes.csv

# %%
# !python ../keras-retinanet/keras_retinanet/bin/train.py --backbone resnet101 --weights path/to/weights.h5 --epochs 100 --snapshot-path path/to/save/dir --tensorboard-dir path/to/tensorboard/dir csv path/to/annotations.csv path/to/classes.csv

# %%
BEGINNING TRAINING
# Out:
#   File "<ipython-input-9-e37c9ce8be7a>", line 1
#     BEGINNING TRAINING
#                      ^
# SyntaxError: invalid syntax

# %%
#TRAIN LegalAgri No Aug ResNet 50  #DONE
# !python ../keras-retinanet/keras_retinanet/bin/train.py --config ../config.ini --lr 1e-4 --reduce-lr-patience 5 --reduce-lr-factor 0.2 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --epochs 100 --batch-size 4 --snapshot-path ../keras-retinanet/snapshots/saves --tensorboard-dir ../../tensor/RetinaNet_Legal_Agri --weighted-average csv ../../images/retina/legal_Agri_noAug/csv/annotations.csv ../../images/retina/legal_Agri_noAug/csv/classes.csv --val-annotations ../../images/retina/legal_Agri_noAug/csv/val_annotations.csv
# Out:
# 2021-04-21 11:45:55.390819: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-04-21 11:45:56.354387: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-21 11:45:56.354902: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-21 11:45:56.391585: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-21 11:45:56.392191: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
#TRAIN LegalTrue No Aug ResNet 50
# !python ../keras-retinanet/keras_retinanet/bin/train.py --lr 1e-4 --reduce-lr-patience 10 --reduce-lr-factor 0.2 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --epochs 100 --batch-size 4 --snapshot-path ../keras-retinanet/snapshots/saves --tensorboard-dir ../../tensor/RetinaNet_Legal_True --weighted-average csv ../../images/retina/legal_True_noAug/csv/annotations.csv ../../images/retina/legal_True_noAug/csv/classes.csv --val-annotations ../../images/retina/legal_True_noAug/csv/val_annotations.csv
# Out:
# 2021-04-20 19:37:12.377492: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-04-20 19:37:13.340402: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-20 19:37:13.341023: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-20 19:37:13.382131: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-20 19:37:13.382507: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
#TRAIN IlegalAgri No Aug ResNet 50
# !python ../keras-retinanet/keras_retinanet/bin/train.py --lr 1e-4 --reduce-lr-patience 4 --reduce-lr-factor 0.5 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --epochs 100 --snapshot-path ../keras-retinanet/snapshots/saves --tensorboard-dir ../../tensor/RetinaNet_Ilegal_Agri --weighted-average csv ../../images/retina/illegal_Agri_noAug/csv/annotations.csv ../../images/retina/illegal_Agri_noAug/csv/classes.csv --val-annotations ../../images/retina/illegal_Agri_noAug/csv/val_annotations.csv
# Out:
# 2021-04-20 19:41:38.872583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-04-20 19:41:39.969332: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-20 19:41:39.970582: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-20 19:41:40.022699: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-20 19:41:40.023345: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
#TRAIN IlegalTrue No Aug ResNet 50
# !python ../keras-retinanet/keras_retinanet/bin/train.py --lr 1e-4 --reduce-lr-patience 4 --reduce-lr-factor 0.5 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --epochs 100 --snapshot-path ../keras-retinanet/snapshots/saves --tensorboard-dir ../../tensor/RetinaNet_Ilegal_True --weighted-average csv ../../images/retina/illegal_True_noAug/csv/annotations.csv ../../images/retina/illegal_True_noAug/csv/classes.csv --val-annotations ../../images/retina/illegal_True_noAug/csv/val_annotations.csv
# Out:
# 2021-04-20 19:58:49.369486: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-04-20 19:58:50.586293: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-20 19:58:50.587431: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-20 19:58:50.637394: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-20 19:58:50.638036: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
#TRAIN WITH AUG

# %%
#TRAIN LegalAgri With Aug ResNet 50  #DONE
# !python ../keras-retinanet/keras_retinanet/bin/train.py --random-transform --lr 1e-4 --reduce-lr-patience 5 --reduce-lr-factor 0.2 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --epochs 100 --batch-size 4 --snapshot-path ../keras-retinanet/snapshots/saves --tensorboard-dir ../../tensor/RetinaNet_Legal_Agri_Aug --weighted-average csv ../../images/retina/legal_Agri_noAug/csv/annotations.csv ../../images/retina/legal_Agri_noAug/csv/classes.csv --val-annotations ../../images/retina/legal_Agri_noAug/csv/val_annotations.csv
# Out:
# 2021-04-20 20:15:42.173033: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-04-20 20:15:43.123875: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-20 20:15:43.124432: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-20 20:15:43.159597: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-20 20:15:43.160263: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
#TRAIN LegalTrue With Aug ResNet 50
# !python ../keras-retinanet/keras_retinanet/bin/train.py --random-transform --lr 1e-4 --reduce-lr-patience 5 --reduce-lr-factor 0.2 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --epochs 100 --batch-size 4 --snapshot-path ../keras-retinanet/snapshots/saves --tensorboard-dir ../../tensor/RetinaNet_Legal_True_Aug --weighted-average csv ../../images/retina/legal_True_noAug/csv/annotations.csv ../../images/retina/legal_True_noAug/csv/classes.csv --val-annotations ../../images/retina/legal_True_noAug/csv/val_annotations.csv
# Out:
# 2021-04-20 20:20:25.879584: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-04-20 20:20:26.821143: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-20 20:20:26.821700: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-20 20:20:26.863979: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-20 20:20:26.864626: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
#TRAIN IlegalAgri With Aug ResNet 50
# !python ../keras-retinanet/keras_retinanet/bin/train.py --random-transform --lr 1e-4 --reduce-lr-patience 10 --reduce-lr-factor 0.2 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --epochs 100 --snapshot-path ../keras-retinanet/snapshots/saves --tensorboard-dir ../../tensor/RetinaNet_Ilegal_Agri_Aug --weighted-average csv ../../images/retina/illegal_Agri_noAug/csv/annotations.csv ../../images/retina/illegal_Agri_noAug/csv/classes.csv --val-annotations ../../images/retina/illegal_Agri_noAug/csv/val_annotations.csv
# Out:
# 2021-04-20 20:42:09.115255: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-04-20 20:42:10.084321: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-20 20:42:10.084894: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-20 20:42:10.126162: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-20 20:42:10.126560: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
#TRAIN IlegalTrue With Aug ResNet 50
# !python ../keras-retinanet/keras_retinanet/bin/train.py --random-transform --lr 1e-4 --reduce-lr-patience 10 --reduce-lr-factor 0.2 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --epochs 100 --snapshot-path ../keras-retinanet/snapshots/saves --tensorboard-dir ../../tensor/RetinaNet_Ilegal_True_Aug --weighted-average csv ../../images/retina/illegal_True_noAug/csv/annotations.csv ../../images/retina/illegal_True_noAug/csv/classes.csv --val-annotations ../../images/retina/illegal_True_noAug/csv/val_annotations.csv
# Out:
# 2021-04-20 21:11:04.798608: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-04-20 21:11:05.767996: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-20 21:11:05.768562: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-20 21:11:05.803405: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-20 21:11:05.804013: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
#EVALUATE

# %%
# !python ../keras-retinanet/keras_retinanet/bin/convert_model.py ../keras-retinanet/snapshots/saves/RetinaNet_Resnet50_Legal_Agri.h5 ../keras-retinanet/snapshots/saves/inference/RetinaNet_Resnet50_Legal_Agri.h5
# Out:
# 2021-04-21 11:11:16.306793: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-21 11:11:19.250404: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-21 11:11:19.251454: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-21 11:11:19.319195: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-21 11:11:19.319981: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
from csv import writer
def append_list_as_row(file_name, list_of_elem):
    # Open file in append mode
    with open(file_name, 'a+', newline='') as write_obj:
        # Create a writer object from csv module
        csv_writer = writer(write_obj)
        # Add contents of list as last row in the csv file
        csv_writer.writerow(list_of_elem)

# %%
#evaluate
from csv import reader
import os
import subprocess
import sys

b=1
x=-1
pic="i"
f = open('../../images/retina/legal_Agri_noAug/csv/val_annotations.csv', 'r')
csv_reader = reader(f)
file = open('../../images/retina/legal_Agri_noAug/csv/tmp'+str(x)+'.csv', "w")
for row in csv_reader:
    if str(row[0]) != pic:
        b=1
        file.close()
        if x >= 0:
            process = subprocess.Popen(['python', '../keras-retinanet/keras_retinanet/bin/evaluate.py', '--iou-threshold','0.3', 'csv', '../../images/retina/legal_Agri_noAug/csv/tmp'+str(x)+'.csv', '../../images/retina/legal_Agri_noAug/csv/classes.csv', '../keras-retinanet/snapshots/saves/inference/RetinaNet_Resnet50_Legal_Agri.h5' ],
                     stdout=subprocess.PIPE, 
                     stderr=subprocess.PIPE)
            stdout = process.communicate()
            #test = os.popen('python ../keras-retinanet/keras_retinanet/bin/evaluate.py --iou-threshold 0.3 csv ../../images/retina/legal_Agri_noAug/csv/tmp'+str(x)+'.csv ../../images/retina/legal_Agri_noAug/csv/classes.csv ../keras-retinanet/snapshots/saves/inference/RetinaNet_Resnet50_Legal_Agri.h5')
            #!python ../keras-retinanet/keras_retinanet/bin/evaluate.py --iou-threshold 0.3 csv ../../images/retina/legal_Agri_noAug/csv/tmp'+str(x)+'.csv ../../images/retina/legal_Agri_noAug/csv/classes.csv ../keras-retinanet/snapshots/saves/inference/RetinaNet_Resnet50_Legal_Agri.h5
            s = str(stdout[0])
            ind1 = s.find('precisions among classes: ',0,len(stdout[0])) + 26
            #print(s[ind: ind+6: 1])
            ind2 = s.find('IoU: ',0,len(stdout[0])) + 5
            #print(s[ind: ind+7: 1])
            row_contents = [str(row[0]),s[ind1: ind1+6: 1],s[ind2: ind2+7: 1]]
            # Append a list as new line to an old csv file
            append_list_as_row('../Retinanet_legal_Agri_noAug.csv', row_contents)
            #results = open('../Retinanet_legal_Agri_noAug'+str(x)+'.csv', "w")
        x+=1
    if b == 1:
        ligne =""
        pic = str(row[0])
        file = open('../../images/retina/legal_Agri_noAug/csv/tmp'+str(x)+'.csv', "w")
        b=0
    if row[0] == pic:
        for e in row:
            ligne = ligne+","+str(e)
        ligne = ligne[1:]
        ligne = ligne+'\r\n'
        file.write(ligne)
        ligne =""
    
        
#file = open('../../images/retina/legal_Agri_noAug/csv/tmp', "w")
#for l in f:
#    for e in l:
#        print(e)
    #ligne = ligne.rstrip("\n")
    #for e in valeur:
    #    ligne = ligne+";"+str(e)
    #ligne = ligne +"\n"
    #f.write(ligne)
f.close()
file.close()
#!python ../keras-retinanet/keras_retinanet/bin/evaluate.py --save-path ../keras-retinanet/snapshots/saves/savemanda --iou-threshold 0.3 csv ../../images/retina/legal_Agri_noAug/csv/val_annotations.csv ../../images/retina/legal_Agri_noAug/csv/classes.csv ../keras-retinanet/snapshots/saves/inference/RetinaNet_Resnet50_Legal_Agri.h5

# %%
# !python ../keras-retinanet/keras_retinanet/bin/evaluate.py --iou-threshold 0.3 csv ../../images/retina/legal_Agri_noAug/csv/.csv ../../images/retina/legal_Agri_noAug/csv/classes.csv ../keras-retinanet/snapshots/saves/inference/RetinaNet_Resnet50_Legal_Agri.h5
# Out:
# 2021-04-21 15:31:37.548323: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Loading model, this may take a second...
# 2021-04-21 15:31:38.542851: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-21 15:31:38.543450: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-21 15:31:38.584622: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-21 15:31:38.585312: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...
