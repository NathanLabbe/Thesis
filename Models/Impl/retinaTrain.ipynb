# %%
#Debug Retinanet 
# !python ../keras-retinanet/keras_retinanet/bin/debug.py  csv ../../images/retina/illegal_True_noAug/csv/val_annotations.csv ../../images/retina/illegal_True_noAug/csv/classes.csv
# Out:
# 2021-03-23 10:41:15.260072: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Traceback (most recent call last):
#   File "../keras-retinanet/keras_retinanet/bin/debug.py", line 321, in <module>
#     main()
#   File "../keras-retinanet/keras_retinanet/bin/debug.py", line 299, in main
#     generator = create_generator(args)
#   File "../keras-retinanet/keras_retinanet/bin/debug.py", line 112, in create_generator
#     **common_args
#   File "../keras-retinanet/keras_retinanet/bin/../../keras_retinanet/preprocessing/csv_generator.py", line 161, in __init__
#     super(CSVGenerator, self).__init__(**kwargs)
#   File "../keras-retinanet/keras_retinanet/bin/../../keras_retinanet/preprocessing/generator.py", line 89, in __init__
#     self.group_images()
#   File "../keras-retinanet/keras_retinanet/bin/../../keras_retinanet/preprocessing/generator.py", line 291, in group_images
# ...

# %%
# !python ../keras-retinanet/keras_retinanet/bin/train.py --freeze-backbone --random-transform --weights {PRETRAINED_MODEL} --batch-size 8 --steps 500 --epochs 15 csv ../../images/retina/illegal_Agri/csv/annotations.csv ../../images/retina/illegal_Agri/csv/classes.csv

# %%
# !python ../keras-retinanet/keras_retinanet/bin/train.py --backbone resnet101 --weights path/to/weights.h5 --epochs 100 --snapshot-path path/to/save/dir --tensorboard-dir path/to/tensorboard/dir csv path/to/annotations.csv path/to/classes.csv

# %%
BEGINNING TRAINING
# Out:
#   File "<ipython-input-9-e37c9ce8be7a>", line 1
#     BEGINNING TRAINING
#                      ^
# SyntaxError: invalid syntax

# %%
#TRAIN LegalAgri No Aug ResNet 50  #DONE
# !python ../keras-retinanet/keras_retinanet/bin/train.py --lr 1e-4 --reduce-lr-patience 5 --reduce-lr-factor 0.2 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --epochs 100 --batch-size 4 --snapshot-path ../keras-retinanet/snapshots/saves --tensorboard-dir ../../tensor/RetinaNet_Legal_Agri --weighted-average csv ../../images/retina/legal_Agri_noAug/csv/annotations.csv ../../images/retina/legal_Agri_noAug/csv/classes.csv --val-annotations ../../images/retina/legal_Agri_noAug/csv/val_annotations.csv
# Out:
# 2021-03-22 17:47:54.032858: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-03-22 17:47:54.985943: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-22 17:47:54.986532: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-22 17:47:55.022903: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-22 17:47:55.023595: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
#TRAIN LegalTrue No Aug ResNet 50
# !python ../keras-retinanet/keras_retinanet/bin/train.py --lr 1e-4 --reduce-lr-patience 2 --reduce-lr-factor 0.5 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --epochs 100 --batch-size 4 --snapshot-path ../keras-retinanet/snapshots/saves --tensorboard-dir ../../tensor/RetinaNet_Legal_True --weighted-average csv ../../images/retina/legal_True_noAug/csv/annotations.csv ../../images/retina/legal_True_noAug/csv/classes.csv --val-annotations ../../images/retina/legal_True_noAug/csv/val_annotations.csv
# Out:
# 2021-03-22 18:02:25.929714: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-03-22 18:02:26.873703: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-22 18:02:26.874290: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-22 18:02:26.911059: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-22 18:02:26.911722: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
#TRAIN IlegalAgri No Aug ResNet 50
# !python ../keras-retinanet/keras_retinanet/bin/train.py --lr 1e-4 --reduce-lr-patience 4 --reduce-lr-factor 0.5 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --epochs 100 --snapshot-path ../keras-retinanet/snapshots/saves --tensorboard-dir ../../tensor/RetinaNet_Ilegal_Agri --weighted-average csv ../../images/retina/illegal_Agri_noAug/csv/annotations.csv ../../images/retina/illegal_Agri_noAug/csv/classes.csv --val-annotations ../../images/retina/illegal_Agri_noAug/csv/val_annotations.csv
# Out:
# 2021-03-22 19:02:15.829135: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-03-22 19:02:16.796483: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-22 19:02:16.797077: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-22 19:02:16.835250: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-22 19:02:16.835950: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
#TRAIN IlegalTrue No Aug ResNet 50
# !python ../keras-retinanet/keras_retinanet/bin/train.py --lr 1e-4 --reduce-lr-patience 4 --reduce-lr-factor 0.5 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --epochs 100 --snapshot-path ../keras-retinanet/snapshots/saves --tensorboard-dir ../../tensor/RetinaNet_Ilegal_True --weighted-average csv ../../images/retina/illegal_True_noAug/csv/annotations.csv ../../images/retina/illegal_True_noAug/csv/classes.csv --val-annotations ../../images/retina/illegal_True_noAug/csv/val_annotations.csv
# Out:
# 2021-03-23 10:54:30.556175: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-03-23 10:54:31.539472: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-23 10:54:31.540078: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-23 10:54:31.577956: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-23 10:54:31.578370: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
#TRAIN WITH AUG

# %%
#TRAIN LegalAgri With Aug ResNet 50  #DONE
# !python ../keras-retinanet/keras_retinanet/bin/train.py --random-transform --lr 1e-4 --reduce-lr-patience 5 --reduce-lr-factor 0.2 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --epochs 100 --batch-size 4 --snapshot-path ../keras-retinanet/snapshots/saves --tensorboard-dir ../../tensor/RetinaNet_Legal_Agri_Aug --weighted-average csv ../../images/retina/legal_Agri_noAug/csv/annotations.csv ../../images/retina/legal_Agri_noAug/csv/classes.csv --val-annotations ../../images/retina/legal_Agri_noAug/csv/val_annotations.csv
# Out:
# 2021-03-23 13:26:41.435855: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-03-23 13:26:42.505665: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-23 13:26:42.506386: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-23 13:26:42.542804: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-23 13:26:42.543473: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
#TRAIN LegalTrue With Aug ResNet 50
# !python ../keras-retinanet/keras_retinanet/bin/train.py --random-transform --lr 1e-4 --reduce-lr-patience 2 --reduce-lr-factor 0.5 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --epochs 100 --batch-size 4 --snapshot-path ../keras-retinanet/snapshots/saves --tensorboard-dir ../../tensor/RetinaNet_Legal_True_Aug --weighted-average csv ../../images/retina/legal_True_noAug/csv/annotations.csv ../../images/retina/legal_True_noAug/csv/classes.csv --val-annotations ../../images/retina/legal_True_noAug/csv/val_annotations.csv
# Out:
# 2021-03-23 13:34:00.666643: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-03-23 13:34:01.644498: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-23 13:34:01.645067: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-23 13:34:01.688084: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-23 13:34:01.688874: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
#TRAIN IlegalAgri With Aug ResNet 50
# !python ../keras-retinanet/keras_retinanet/bin/train.py --random-transform --lr 1e-4 --reduce-lr-patience 4 --reduce-lr-factor 0.5 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --epochs 100 --snapshot-path ../keras-retinanet/snapshots/saves --tensorboard-dir ../../tensor/RetinaNet_Ilegal_Agri_Aug --weighted-average csv ../../images/retina/illegal_Agri_noAug/csv/annotations.csv ../../images/retina/illegal_Agri_noAug/csv/classes.csv --val-annotations ../../images/retina/illegal_Agri_noAug/csv/val_annotations.csv
# Out:
# 2021-03-23 14:12:51.844958: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-03-23 14:12:52.819254: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-23 14:12:52.819849: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-23 14:12:52.866323: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-23 14:12:52.867060: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
#TRAIN IlegalTrue With Aug ResNet 50
# !python ../keras-retinanet/keras_retinanet/bin/train.py --random-transform --lr 1e-4 --reduce-lr-patience 4 --reduce-lr-factor 0.5 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --epochs 100 --snapshot-path ../keras-retinanet/snapshots/saves --tensorboard-dir ../../tensor/RetinaNet_Ilegal_True_Aug --weighted-average csv ../../images/retina/illegal_True_noAug/csv/annotations.csv ../../images/retina/illegal_True_noAug/csv/classes.csv --val-annotations ../../images/retina/illegal_True_noAug/csv/val_annotations.csv
# Out:
# 2021-03-23 13:42:48.145677: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-03-23 13:42:49.114872: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-23 13:42:49.115413: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-23 13:42:49.150556: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-23 13:42:49.151733: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...

# %%
#EVALUATE

# %%
#evaluate
# !python ../keras-retinanet/keras_retinanet/bin/evaluate.py csv ../../images/retina/illegal_Agri_noAug/csv/val_annotations.csv ../../images/retina/illegal_Agri_noAug/csv/classes.csv ../keras-retinanet/snapshots/saves/inference/model.h5
# Out:
# 2021-02-25 15:16:35.953447: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Loading model, this may take a second...
# 2021-02-25 15:16:36.941933: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-02-25 15:16:36.942522: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-02-25 15:16:36.978725: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-02-25 15:16:36.979332: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.91GiB deviceMemoryBandwidth: 451.17GiB/s
# ...
